# %% [markdown]
# # Chloe Wang, Qihan Guan, Michael Harris #
# ### BAX-422 Group 5 ###
# ### March 9, 2021 ###

# %%
pip install pyzipcode
# Out:
# Collecting pyzipcode
#   Downloading pyzipcode-3.0.1.tar.gz (1.9 MB)
# Building wheels for collected packages: pyzipcode
#   Building wheel for pyzipcode (setup.py): started
#   Building wheel for pyzipcode (setup.py): finished with status 'done'
#   Created wheel for pyzipcode: filename=pyzipcode-3.0.1-py3-none-any.whl size=1932419 sha256=37d9db666e6db5b2b6a71ac09875e78788eff76a6ee3eb7e22c1bc4658a52904
#   Stored in directory: c:\users\dvcgu\appdata\local\pip\cache\wheels\f6\01\8e\7424c7e867eb5db7bb9531b09b4d968f23e5ac45ec5e7c3cb3
# Successfully built pyzipcode
# Installing collected packages: pyzipcode
# Successfully installed pyzipcode-3.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import packages
from bs4 import BeautifulSoup, Tag
from urllib.request import Request, urlopen
from urllib.request import urlopen
import requests
import time
import warnings
import requests
import os
import json
import re
import codecs
import urllib.request, urllib.error, urllib.parse
import shutil
from lxml import html
from time import sleep
from itertools import zip_longest
from pyzipcode import ZipCodeDatabase
import pandas as pd
import numpy as np

# %%
# Ask Input for Car make.
make = str(input("Enter Make(Press enter directly to omit): ")).lower()

# Ask Input for Model
model = str(input("Enter Model(Press enter directly to omit): ")).lower()

# Ask Input for Minimum Year
min_year = ''
while True: 
  year1 = int(input("Please enter vehicle minimum year: (1981-2021): ")) 
  min_year = str(year1)
  if year1 not in range(1981,2022):
    print("**Please enter a valid year**")
    continue
  else:
    break


# Ask Input for Maximum Year
max_year = ''
while True: 
  year2 = int(input("Please enter vehicle maximum year: (1981-2021): ")) 
  max_year = str(year2)
  if year2 not in range(1981,2022):
    print("**Please enter a valid year**")
    continue
  elif year2 < int(min_year):
    print("**Maximum year cannot be older than minimum year**")
    continue
  else:
    break

# Ask Input for Zip Code
url_geo=''
while True: 
  zipcode = str(input("Please enter your 5-digit Zip Code: ")) 
  zipdb = ZipCodeDatabase()
  try: 
    geoinfo = zipdb[zipcode]
    url_geo = str(geoinfo.city).lower().replace(" ","-") +"-"+str(geoinfo.state).lower()+"-"+str(zipcode)
  except: 
    print("**Please enter a valid zipcode**") 
    continue
  else:
    break
print(url_geo)
# Ask Input for Radius
radius=''
while True: 
  radius = str(input("Please enter your search radius in miles (10/25/50/75/100/200/300/400/500/ 0 for any): ")) 
  if radius not in ['10','25','50','75','100','200','300','400','500','0']:
    print("**Please enter a valid radius**")
    continue
  else:
    break
# Out:
# Enter Make(Press enter directly to omit): toyota
# Enter Model(Press enter directly to omit): camry
# Please enter vehicle minimum year: (1981-2021): 2019
# Please enter vehicle maximum year: (1981-2021): 2020
# Please enter your 5-digit Zip Code: 90021
# los-angeles-ca-90021
# Please enter your search radius in miles (10/25/50/75/100/200/300/400/500/ 0 for any): 50

# %%
# Compose the URL based on user input. Set to 100 items per page to miminze get requests
url = str("https://www.autotrader.com/cars-for-sale/all-cars/"+make+"/"+model+"/"+url_geo+"?dma=&searchRadius="+
radius+"&location=&marketExtension=include&startYear="+min_year+"&endYear="+max_year+"&isNewSearch=true&showAccelerateBanner=false&sortBy=relevance&numRecords=100")

print(url)
# Out:
# https://www.autotrader.com/cars-for-sale/all-cars/toyota/camry/los-angeles-ca-90021?dma=&searchRadius=50&location=&marketExtension=include&startYear=2019&endYear=2020&isNewSearch=true&showAccelerateBanner=false&sortBy=relevance&numRecords=100

# %% [markdown]
# ### Save all the listed vehicle URLs under the user input criteria

# %%
# Scrape All URLs from Search:
header = ({'User-Agent':'Mozilla/5.0'}) 

# Initialize a list to save the item urls
url_list = []

# Loop thorugh all the pages available 
i = 0 # set a intial counter 0
while True:
    URL = url + '&firstRecord=' + str(i*100) #Autotrader uses a multiplier of num_records_per_page to navigate to different pages
    response = requests.get(URL, headers = header)
    soup = BeautifulSoup(response.content, 'html.parser')
    pagebuttons = soup.find_all('li', {'class':'active'})
    out_of_bound = True
    
    #Check in page number out-of-bound
    for buttons in pagebuttons:
        if(len(buttons.find_all('a', {'role':'button'}))!=0):
            out_of_bound = False
    
    if out_of_bound == True: # Stop if page number out-of-bound
        break
    #else, scrape url of each listed vehicle for sale
    else:
        items = soup.findAll('div',{"class":"display-flex justify-content-between"})
        for item in items:
            a = item.find("a")
            if not a:
                continue
            url_simplify = 'https://www.autotrader.com' + a['href']
            url_list.append(url_simplify + "\n")
            print(url_simplify)
        #set a time lapse
        time.sleep(4)
        
    #increment counter
    i = i+1
# Out:
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576657334&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dtrue&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=alpha
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577036924&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&clickType=spotlight
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=565600684&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&clickType=spotlight
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579150333&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579200341&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579274411&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=574191346&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578975571&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575181641&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&clickType=spotlight
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578972640&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577036915&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577036923&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577171070&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576237361&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=574558076&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579098714&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579401054&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578893188&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=565994536&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577968538&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=565600684&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577221796&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579042382&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578547376&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577036924&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576328048&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578893189&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577227667&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579316956&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576629467&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579042380&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373327&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578524979&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577666752&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=570684106&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577639526&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577036897&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576269796&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578229611&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578498853&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578498917&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577754629&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=564658640&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578757999&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576705118&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576759295&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578931419&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578616888&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=568400685&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=566310168&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578503127&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577760903&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577216137&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576657334&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575181641&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=571159970&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577031354&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578498897&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578335562&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575464025&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575136609&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576534785&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576997459&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576068067&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576705160&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578353910&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577979269&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578002345&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=570597637&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577418119&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578625184&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576088713&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=572700208&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# ...
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579506564&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=574999880&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579531004&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578975577&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579259807&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579517830&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579531455&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578455952&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579411551&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579073701&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579073702&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373222&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579518932&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579542706&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373330&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373337&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373320&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373225&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373216&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373333&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373351&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373241&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373219&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576373346&zip=90021&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D90021%26city%3DLos%2BAngeles%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DCA%26firstRecord%3D500%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=500&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing

# %%
#Check the total number of URLs saved
len(url_list)
# Out:
# 590

# %% [markdown]
# ### Open all the URLs and save the listing vehicles' pages in a directory

# %%
#Compose a filename based on the user input
file_name = make+'_'+model+'_'+min_year+'_'+max_year+'_'+str(zipcode)+'_'+str(radius)+'miles'

#Write all listed vehicle's url to file_name.txt
with open(os.getcwd()+'/'+file_name+'.txt', 'w+') as filehandle:
    for item_url in url_list:
        filehandle.write('%s' % item_url)

# %%
#read the txt file and save the listed vehicles' pages as html files
cars = open(os.getcwd()+'/'+file_name+'.txt', 'r').read().split('\n')
headers = {'User-Agent':'Mozilla/5.0'}  

#create path for 'file_name' folder
path = os.path.join(os.getcwd() , file_name)
if not os.path.exists(path):
    os.makedirs(path)

try:
    #Download each of the pages(URLs) into the folder 'file_name'
    for URL in cars[0:243]:
        listing_id = re.search(r'\?listingId=([0-9]+)&', URL).group(1) #Use listing ID as name for each html file
        page = requests.get(URL, headers=headers) 
        with open(os.path.join(path, str(listing_id)+'.html'), 'w+', encoding="utf-8") as filehandle:
            filehandle.write(page.text)

        #put a 3 sec pause between queries
        time.sleep(3)
except:
    print('Problem with connection...')

# %%
#Check how many files saved successfully
list = os.listdir(path) 
print(len(list))
# Out:
# 231

# %% [markdown]
# ### Open each saved html file and save the data we want in a pd dataframe
# For each listed vehicle, we will save the following information:
#
# Listing ID, Vehicle Condition, Year, Make, Model, Trim Level, List Price, Mileage, Transimission, Drivetrain(FWD/RWD/AWD), Exterior Color, Interior Color, Engine Type, City MPG, Highway Mpg, Seller Type(Private or Dealer), Seller Name, Seller Rating, Seller Number of Reviews, Seller Street Address, Seller City, Seller State, Seller Zipcode, Seller Phone Number

# %%
#initialize a data frame to save 

vehicle_info = pd.DataFrame(columns=['Listing ID','Condition', 'Year', 'Make', 'Model','Trim Level','List Price','Mileage',
                                    'Exterior Color', 'Interior Color','Engine Type','Transmission','Drivetrain(FWD/RWD/AWD)', 
                                     'City MPG', 'Highway MPG', 'Seller Type', 'Seller Name','Seller Rating',
                                    'Number of Reviews','Seller Street Address', 'Seller City','Seller State',
                                     'Seller Zipcode','Seller Phone Number'])

for i in range(0, len(list)):
    try:
        page = list[i]
        listing_id = re.search(r'([0-9]+)\.html',list[i]).group(1) #Get Listing ID
        page_file = open(path + '\\' + page, 'r', encoding="utf-8").read() 
        soup = BeautifulSoup(page_file, 'html.parser')

        #selector command for Vehicle Condition
        try:
            title_raw = soup.find('h1', class_ ='text-bold text-size-400 text-size-sm-700').text
            condition = re.search(r'([UCN][a-z]+) ([0-9]{4}) ([A-Za-z]+) ([A-Za-z0-9]+)',title_raw).group(1)
        except:
            condition = None
            
        #selector command for Vehicle Year
        try:
            year = re.search(r'([UCN][a-z]+) ([0-9]{4}) ([A-Za-z]+) ([A-Za-z0-9]+)',title_raw).group(2)
        except:
            year = None

        #selector command for Vehicle Make
        try:
            make = re.search(r'([UCN][a-z]+) ([0-9]{4}) ([A-Za-z]+) ([A-Za-z0-9]+)',title_raw).group(3)
        except:
            make = None
        
        #selector command for Vehicle Model
        try:
            model = re.search(r'([UCN][a-z]+) ([0-9]{4}) ([A-Za-z]+) ([A-Za-z0-9]+)',title_raw).group(4)
        except:
            model = None
        
        #selector command for Vehicle Trim Level
        try:
            trim = re.search(r'([UCN][a-z]+) ([0-9]{4}) ([A-Za-z]+) ([A-Za-z0-9]+) (.+)',title_raw).group(5)
        except:
            trim = None
        
        #selector command for List Price
        #In most cases, a net price will be displayed
        try:
            price = int(soup.find('span',{'class':'first-price'}).text.replace(',',''))
        except:#For new vehicles, some of them will display only the MSRP as price
            try:
                price_raw = soup.find('span', {'class':'padding-left-2 padding-bottom-1 text-normal second-price'}).find('span', {'class':'text-bold'}).text
                price = int(price_raw.replace(',',''))  
            except:
                price = None
        
        #selector command for Vehicle Mileage
        try:
            #find the element following the mileage icon
            m = soup.find('div', {'style':'background:url(https://www.autotrader.com/content/dam/autotrader/findcar/vdp/specifications/all_spec_icons.svg) -191px -74px;height:25px;width:30px'})
            mileage_raw = re.search(r'(.+) miles',m.parent.find_next_sibling('div').text).group(1)
            mileage = int(mileage_raw.replace(',',''))
        except:
            mileage = None
        
        #selector command for Exterior Color
        try:
            #find the element following the exterior color icon
            excol = soup.find_all('div', {'class':'swatch'})[0]
            extcolor = re.search(r'(.+) Exterior',excol.parent.parent.nextSibling.text).group(1)
        except:
            extcolor = None
        
        #selector command for Interior Color
        try:
            #find the element following the interior color icon
            incol = soup.find_all('div', {'class':'swatch'})[1]
            intcolor = re.search(r'(.+) Interior',incol.parent.parent.nextSibling.text).group(1)
        except:
            intcolor = None
        
        #selector command for Engine Type
        try:
            eng = soup.find('div', {'aria-label':"ENGINE_DESCRIPTION"})
            engine = eng.parent.find_next_sibling('div').text
        except:
            engine = None
        
        #selector command for Transmission
        try:
            trans = soup.find('div', {'aria-label':"TRANSMISSION"})
            transmission = trans.parent.find_next_sibling('div').text
        except:
            transmission = None
        
        #selector command for Drivetrain
        try:
            drive = soup.find('div', {'aria-label':"DRIVE TYPE"})
            drivetrain = drive.parent.find_next_sibling('div').text
        except:
            drivetrain = None
            
        #selector command for City MPG
        try:
            mpg = soup.find('div', {'aria-label':"MPG"}).parent.find_next_sibling('div').text
            city_mpg = re.search(r'([0-9]+) City / ([0-9]+) Highway',mpg).group(1)
        except:
            city_mpg = None
            
        #selector command for Highway MPG
        try:
            mpg = soup.find('div', {'aria-label':"MPG"}).parent.find_next_sibling('div').text
            highway_mpg = re.search(r'([0-9]+) City / ([0-9]+) Highway',mpg).group(2)
        except:
            highway_mpg = None
            
        #Get Seller's type (either private seller or dealer)
        #if find the h2 class for 'private seller' heading, then it's private seller
        if(len(soup.find_all('h2', {'class':'text-bold padding-bottom-3'}))!=0):
            seller_type = 'Private Seller'
        #otherwise, the seller is a dealer    
        else:
            seller_type = 'Dealer'
            
        #Get Seller Name
        if seller_type == 'Dealer':
            try:
                seller_name = soup.find('h2', {'class':"text-left text-bold text-size-20 display-inline"}).text
            except:
                try:
                    seller_name = soup.find('h2', {'class':"text-left text-bold text-size-20"}).text
                except:
                    seller_name = None
        else:
            seller_name = None #Set to 'None' for private sellers because Not Applicable
            
        #Get Seller Rating
        if seller_type == 'Dealer':
            try:
                seller_rating = float(soup.find('span', {'class': "text-bold text-subdued"}).text)
            except:
                seller_rating = None
        else:
            seller_rating = None #Set to 'None' for private sellers because Not Applicable
        
        #Get Number of Reviews for the Seller
        if seller_type == 'Dealer':
            try:
                num_reviews_raw = soup.find('a', {'class': "cursor-pointer padding-left-1"}).text
                num_reviews = int(re.search(r'([0-9]+)', num_reviews_raw).group(1))
            except:
                num_reviews = 0 
        else:
            num_reviews = None #Set to 'None' for private sellers because Not Applicable
        
        #Get Seller Street Address
        addrs = soup.find_all('div', {'data-cmp': "address"})
        address = ''
        for addr in addrs:
            for line in addr:
                address = address + line.text
        try:
            seller_street = re.search(r'([0-9]+ [A-Z].+), [A-Za-z\s]+, ', address).group(1)
        except:
            seller_street = None
            
        #Get Seller City
        try:
            seller_city = re.search(r'(.*,)?\s?(.*), [A-Z]{2} [0-9]{5}', address).group(2)
        except:
            seller_city = None  
            
        #Get Seller State
        try:
            seller_state = re.search(r', ([A-Z]{2}) ([0-9]{5})', address).group(1)
        except:
            seller_state = None
        
        #Get Seller Zipcode
        try:
            seller_zip = re.search(r', ([A-Z]{2}) ([0-9]{5})', address).group(2)
        except:
            seller_zip = None
        
        #Get Seller Phone Number
        try:
            seller_phone = soup.find('span', {'data-cmp':'phoneNumber'}).text
        except:
            seller_phone = None
            
        #save this iteration's result to the i-th row of the dataframe
        vehicle_info.loc[i] = [listing_id, condition, year, make, model, trim, price, mileage, extcolor, intcolor, engine, transmission, drivetrain, city_mpg, 
                       highway_mpg, seller_type, seller_name, seller_rating, num_reviews, seller_street, seller_city, seller_state,
                       seller_zip, seller_phone]

           
    except:
        print('Error with: ' + page)

# %% [markdown]
# ### View Saved Data

# %%
vehicle_info
# Out:
#     Listing ID Condition  Year    Make  Model   Trim Level List Price Mileage  \
# 0    548773684      Used  2019  Toyota  Camry           SE      17780   30141
# 1    555644427      Used  2019  Toyota  Camry     LE Sedan      17995   34771
# 2    556851039      Used  2019  Toyota  Camry           LE      16960   32102
# 3    557950900      Used  2019  Toyota  Camry            L      16990   32465
# 4    558041097      Used  2019  Toyota  Camry           SE      22199    4030
# ..         ...       ...   ...     ...    ...          ...        ...     ...
# 226  579416018      Used  2020  Toyota  Camry  SE Sedan 4D      27000    3374
# 227  579472179      Used  2020  Toyota  Camry      XSE AWD      29780    7529
# 228  579472191      Used  2019  Toyota  Camry           SE      20990   10946
# 229  579482405      Used  2019  Toyota  Camry           LE      20998   30509
# 230  579495703      Used  2019  Toyota  Camry     LE Sedan      15499   55978
#
#                 Exterior Color Interior Color  ... Highway MPG  \
# 0               Midnight Black            Ash  ...          41
# 1                         Gray          Black  ...          41
# 2                  Super White          Black  ...          41
# 3             Celestial Silver          Black  ...          41
# 4      Midnight Black Metallic          Black  ...          39
# ..                         ...            ...  ...         ...
# 226                       Blue           Gray  ...          47
# 227          Predawn Gray Mica          Black  ...        None
# 228                        Red          Black  ...          41
# 229  Celestial Silver Metallic          Black  ...          41
# 230                      Black           Gray  ...          41
#
#         Seller Type                                        Seller Name  \
# 0            Dealer                                      Carson Nissan
# 1            Dealer                                       Mac Auto Inc
# 2            Dealer                        DCH Subaru of Thousand Oaks
# 3            Dealer                                      Carson Nissan
# 4            Dealer                            Montclair Auto Exchange
# ..              ...                                                ...
# 226  Private Seller                                               None
# 227          Dealer  Vroom - Get It Delivered Nationwide, Contact-Free
# 228          Dealer  Vroom - Get It Delivered Nationwide, Contact-Free
# 229          Dealer                      AutoNation Chevrolet Valencia
# 230          Dealer                                      OC Chief Auto
#
#     Seller Rating Number of Reviews          Seller Street Address  \
# 0             4.6              1595                1505 E 223RD ST
# 1             4.6                66      351 West Imperial Highway
# 2             4.8                61              3725 AUTO MALL DR
# 3             4.6              1595                1505 E 223RD ST
# 4             4.2               110              10440 CENTRAL AVE
# ..            ...               ...                            ...
# 226          None              None                           None
# 227          None                 0                           None
# 228          None                 0                           None
# 229           4.6              1033  23649 West Valencia Boulevard
# 230           3.9                58   2082 SE BRISTOL ST, SUITE 12
#
#           Seller City Seller State Seller Zipcode Seller Phone Number
# 0              CARSON           CA          90745      (424) 349-3025
# 1            La Habra           CA          90631    1 (866) 696-1995
# 2    WESTLAKE VILLAGE           CA          91362      (805) 601-6496
# 3              CARSON           CA          90745      (424) 349-3025
# 4           MONTCLAIR           CA          91763      (909) 480-2452
# ..                ...          ...            ...                 ...
# 226   Rowland Heights           CA          91748                None
# 227              None         None           None    1 (844) 394-1756
# 228              None         None           None    1 (844) 394-1756
# 229          Valencia           CA          91355      (661) 383-0248
# 230     NEWPORT BEACH           CA          92660      (949) 432-9122
#
# [231 rows x 24 columns]

# %% [markdown]
# ### Save Data to MongoDB

# %%
#Connect to MongoDB
import pymongo
from pymongo import MongoClient

client = MongoClient('localhost', 27017)

db = client[file_name] #use the user input criteria to compose a database name
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'toyota_carmy_2019_2020_90021_50miles')

# %% [markdown]
# Save data from dataframe to MongoDB collection row by row:

# %%
#Show database name
print(file_name)
mycollection = db[file_name]
print(mycollection)
# Out:
# toyota_carmy_2019_2020_90021_50miles
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'toyota_carmy_2019_2020_90021_50miles'), 'toyota_carmy_2019_2020_90021_50miles')

# %%
for i in vehicle_info.index:
    #If seller is a dealer, insert all info
    if vehicle_info['Seller Type'][i] == 'Dealer':
        listing_id = int(vehicle_info['Listing ID'][i])
        try:
            Condition = str(vehicle_info['Condition'][i])
        except:
            Condition = None
        try:
            Year = int(vehicle_info['Year'][i])
        except:
            Year = None
        try:
            Make = str(vehicle_info['Make'][i])
        except:
            Make = None
        try:
            Model = str(vehicle_info['Model'][i])
        except:
            Model = None
        try:
            TrimLevel = str(vehicle_info['Trim Level'][i])
        except:
            TrimLevel = None
        try:
            ListPrice = int(vehicle_info['List Price'][i])
        except:
            ListPrice = None
        try:
            Mileage = int(vehicle_info['Mileage'][i])
        except:
            Mileage = None
        try:
            ExteriorColor = str(vehicle_info['Exterior Color'][i])
        except:
            ExteriorColor = None
        try:
            InteriorColor = str(vehicle_info['Interior Color'][i])
        except:
            InteriorColor = None
        try:
            EngineType = str(vehicle_info['Engine Type'][i])
        except:
            EngineType = None
        try:
            Transmission = str(vehicle_info['Transmission'][i])
        except:
            Transmission = None
        try:
            Drivetrain = str(vehicle_info['Drivetrain(FWD/RWD/AWD)'][i])
        except:
            Drivetrain = None
        try:
            CityMPG = int(vehicle_info['City MPG'][i])
        except:
            CityMPG = None
        try:
            HighwayMPG = int(vehicle_info['Highway MPG'][i])
        except:
            HighwayMPG = None
        SellerType = str(vehicle_info['Seller Type'][i])
        try:
            SellerName = str(vehicle_info['Seller Name'][i])
        except:
            SellerName = None
        try:
            SellerRating = float(vehicle_info['Seller Rating'][i])
        except:
            SellerRating = None
        try:
            NumberofReviews = int(vehicle_info['Number of Reviews'][i])
        except:
            NumberofReviews = None
        try:
            SellerStreetAddress = str(vehicle_info['Seller Street Address'][i])
        except:
            SellerStreetAddress = None
        try:
            SellerCity = str(vehicle_info['Seller City'][i])
        except:
            SellerCity = None
        try:
            SellerState = str(vehicle_info['Seller State'][i])
        except:
            SellerState = None
        try:
            SellerZipcode = str(vehicle_info['Seller Zipcode'][i])
        except:
            SellerZipcode = None
        try:
            SellerPhoneNumber = str(vehicle_info['Seller Phone Number'][i])
        except:
            SellerPhoneNumber = None
        
        mydict = {
            '_id' : listing_id,
            'Condition': Condition,
            'Year': Year,
            'Make': Make,
            'Model': Model,
            'Trim Level': TrimLevel,
            'List Price': ListPrice,
            'Mileage': Mileage,
            'Exterior Color': ExteriorColor,
            'Interior Color': InteriorColor,
            'Engine Type': EngineType,
            'Transmission': Transmission,
            'Drivetrain': Drivetrain,
            'City MPG': CityMPG,
            'Highway MPG': HighwayMPG,
            'Seller Type': SellerType,
            'Seller Name': SellerName,
            'Seller Rating': SellerRating,
            'Number of Reviews': NumberofReviews,
            'Seller Street Address': SellerStreetAddress,
            'Seller City': SellerCity,
            'Seller State': SellerState,
            'Seller Zipcode': SellerZipcode,
            'Seller Phone Number': SellerPhoneNumber 
        }
        
        #insert this listed vehicle's data to MongoDB database 
        mycollection.insert_one(mydict)
    
    #If seller is a private seller, do not save Seller Name, Seller Rating or Number of Reviews
    else:
        listing_id = int(vehicle_info['Listing ID'][i])
        try:
            Condition = str(vehicle_info['Condition'][i])
        except:
            Condition = None
        try:
            Year = int(vehicle_info['Year'][i])
        except:
            Year = None
        try:
            Make = str(vehicle_info['Make'][i])
        except:
            Make = None
        try:
            Model = str(vehicle_info['Model'][i])
        except:
            Model = None
        try:
            TrimLevel = str(vehicle_info['Trim Level'][i])
        except:
            TrimLevel = None
        try:
            ListPrice = int(vehicle_info['List Price'][i])
        except:
            ListPrice = None
        try:
            Mileage = int(vehicle_info['Mileage'][i])
        except:
            Mileage = None
        try:
            ExteriorColor = str(vehicle_info['Exterior Color'][i])
        except:
            ExteriorColor = None
        try:
            InteriorColor = str(vehicle_info['Interior Color'][i])
        except:
            InteriorColor = None
        try:
            EngineType = str(vehicle_info['Engine Type'][i])
        except:
            EngineType = None
        try:
            Transmission = str(vehicle_info['Transmission'][i])
        except:
            Transmission = None
        try:
            Drivetrain = str(vehicle_info['Drivetrain(FWD/RWD/AWD)'][i])
        except:
            Drivetrain = None
        try:
            CityMPG = int(vehicle_info['City MPG'][i])
        except:
            CityMPG = None
        try:
            HighwayMPG = int(vehicle_info['Highway MPG'][i])
        except:
            HighwayMPG = None
        SellerType = str(vehicle_info['Seller Type'][i])
        try:
            SellerStreetAddress = str(vehicle_info['Seller Street Address'][i])
        except:
            SellerStreetAddress = None
        try:
            SellerCity = str(vehicle_info['Seller City'][i])
        except:
            SellerCity = None
        try:
            SellerState = str(vehicle_info['Seller State'][i])
        except:
            SellerState = None
        try:
            SellerZipcode = str(vehicle_info['Seller Zipcode'][i])
        except:
            SellerZipcode = None
        try:
            SellerPhoneNumber = str(vehicle_info['Seller Phone Number'][i])
        except:
            SellerPhoneNumber = None
        
        mydict = {
            '_id' : listing_id,
            'Condition': Condition,
            'Year': Year,
            'Make': Make,
            'Model': Model,
            'Trim Level': TrimLevel,
            'List Price': ListPrice,
            'Mileage': Mileage,
            'Exterior Color': ExteriorColor,
            'Interior Color': InteriorColor,
            'Engine Type': EngineType,
            'Transmission': Transmission,
            'Drivetrain': Drivetrain,
            'City MPG': CityMPG,
            'Highway MPG': HighwayMPG,
            'Seller Type': SellerType,
            'Seller Street Address': SellerStreetAddress,
            'Seller City': SellerCity,
            'Seller State': SellerState,
            'Seller Zipcode': SellerZipcode,
            'Seller Phone Number': SellerPhoneNumber 
        }
        
        #insert this listed vehicle's data to MongoDB database 
        mycollection.insert_one(mydict)
        
    print('Row '+str(i)+' successfully inserted!\n')
# Out:
# Row 0 successfully inserted!
#
# Row 1 successfully inserted!
#
# Row 2 successfully inserted!
#
# Row 3 successfully inserted!
#
# Row 4 successfully inserted!
#
# Row 5 successfully inserted!
#
# Row 6 successfully inserted!
#
# Row 7 successfully inserted!
#
# Row 8 successfully inserted!
#
# Row 9 successfully inserted!
#
# Row 10 successfully inserted!
#
# Row 11 successfully inserted!
#
# Row 12 successfully inserted!
#
# Row 13 successfully inserted!
#
# Row 14 successfully inserted!
#
# Row 15 successfully inserted!
#
# Row 16 successfully inserted!
#
# Row 17 successfully inserted!
#
# Row 18 successfully inserted!
#
# Row 19 successfully inserted!
#
# Row 20 successfully inserted!
#
# Row 21 successfully inserted!
#
# Row 22 successfully inserted!
#
# Row 23 successfully inserted!
#
# Row 24 successfully inserted!
#
# Row 25 successfully inserted!
#
# Row 26 successfully inserted!
#
# Row 27 successfully inserted!
#
# Row 28 successfully inserted!
#
# Row 29 successfully inserted!
#
# Row 30 successfully inserted!
#
# Row 31 successfully inserted!
#
# Row 32 successfully inserted!
#
# Row 33 successfully inserted!
#
# Row 34 successfully inserted!
#
# Row 35 successfully inserted!
#
# Row 36 successfully inserted!
#
# Row 37 successfully inserted!
#
# Row 38 successfully inserted!
#
# Row 39 successfully inserted!
#
# Row 40 successfully inserted!
#
# Row 41 successfully inserted!
#
# Row 42 successfully inserted!
#
# Row 43 successfully inserted!
#
# Row 44 successfully inserted!
#
# Row 45 successfully inserted!
#
# Row 46 successfully inserted!
#
# Row 47 successfully inserted!
#
# Row 48 successfully inserted!
#
# Row 49 successfully inserted!
#
# Row 50 successfully inserted!
#
# Row 51 successfully inserted!
#
# Row 52 successfully inserted!
#
# Row 53 successfully inserted!
#
# Row 54 successfully inserted!
#
# Row 55 successfully inserted!
#
# Row 56 successfully inserted!
#
# Row 57 successfully inserted!
#
# Row 58 successfully inserted!
#
# Row 59 successfully inserted!
#
# Row 60 successfully inserted!
#
# Row 61 successfully inserted!
#
# Row 62 successfully inserted!
#
# Row 63 successfully inserted!
#
# Row 64 successfully inserted!
#
# Row 65 successfully inserted!
#
# Row 66 successfully inserted!
#
# Row 67 successfully inserted!
#
# Row 68 successfully inserted!
#
# Row 69 successfully inserted!
#
# Row 70 successfully inserted!
#
# Row 71 successfully inserted!
#
# Row 72 successfully inserted!
#
# Row 73 successfully inserted!
#
# Row 74 successfully inserted!
#
# Row 75 successfully inserted!
#
# Row 76 successfully inserted!
#
# Row 77 successfully inserted!
#
# Row 78 successfully inserted!
#
# Row 79 successfully inserted!
#
# Row 80 successfully inserted!
#
# Row 81 successfully inserted!
#
# Row 82 successfully inserted!
#
# Row 83 successfully inserted!
#
# Row 84 successfully inserted!
#
# Row 85 successfully inserted!
#
# Row 86 successfully inserted!
#
# Row 87 successfully inserted!
#
# Row 88 successfully inserted!
#
# Row 89 successfully inserted!
#
# Row 90 successfully inserted!
#
# Row 91 successfully inserted!
#
# Row 92 successfully inserted!
#
# Row 93 successfully inserted!
#
# Row 94 successfully inserted!
#
# Row 95 successfully inserted!
#
# Row 96 successfully inserted!
#
# Row 97 successfully inserted!
#
# Row 98 successfully inserted!
#
# Row 99 successfully inserted!
#
# Row 100 successfully inserted!
#
# Row 101 successfully inserted!
#
# Row 102 successfully inserted!
#
# Row 103 successfully inserted!
#
# Row 104 successfully inserted!
#
# Row 105 successfully inserted!
#
# Row 106 successfully inserted!
#
# Row 107 successfully inserted!
#
# Row 108 successfully inserted!
#
# Row 109 successfully inserted!
#
# Row 110 successfully inserted!
#
# Row 111 successfully inserted!
#
# Row 112 successfully inserted!
#
# Row 113 successfully inserted!
#
# Row 114 successfully inserted!
#
# Row 115 successfully inserted!
#
# Row 116 successfully inserted!
#
# Row 117 successfully inserted!
#
# Row 118 successfully inserted!
#
# Row 119 successfully inserted!
#
# Row 120 successfully inserted!
#
# Row 121 successfully inserted!
#
# Row 122 successfully inserted!
#
# Row 123 successfully inserted!
#
# Row 124 successfully inserted!
#
# Row 125 successfully inserted!
#
# Row 126 successfully inserted!
#
# Row 127 successfully inserted!
#
# Row 128 successfully inserted!
#
# Row 129 successfully inserted!
#
# Row 130 successfully inserted!
#
# Row 131 successfully inserted!
#
# Row 132 successfully inserted!
#
# Row 133 successfully inserted!
#
# Row 134 successfully inserted!
#
# Row 135 successfully inserted!
#
# Row 136 successfully inserted!
#
# Row 137 successfully inserted!
#
# Row 138 successfully inserted!
#
# Row 139 successfully inserted!
#
# Row 140 successfully inserted!
#
# Row 141 successfully inserted!
#
# Row 142 successfully inserted!
#
# Row 143 successfully inserted!
#
# Row 144 successfully inserted!
#
# Row 145 successfully inserted!
#
# Row 146 successfully inserted!
#
# Row 147 successfully inserted!
#
# Row 148 successfully inserted!
#
# Row 149 successfully inserted!
#
# Row 150 successfully inserted!
#
# Row 151 successfully inserted!
#
# Row 152 successfully inserted!
#
# Row 153 successfully inserted!
#
# Row 154 successfully inserted!
#
# Row 155 successfully inserted!
#
# Row 156 successfully inserted!
#
# Row 157 successfully inserted!
#
# Row 158 successfully inserted!
#
# Row 159 successfully inserted!
#
# Row 160 successfully inserted!
#
# Row 161 successfully inserted!
#
# Row 162 successfully inserted!
#
# Row 163 successfully inserted!
#
# Row 164 successfully inserted!
#
# Row 165 successfully inserted!
#
# Row 166 successfully inserted!
#
# Row 167 successfully inserted!
#
# Row 168 successfully inserted!
#
# Row 169 successfully inserted!
#
# Row 170 successfully inserted!
#
# Row 171 successfully inserted!
#
# Row 172 successfully inserted!
#
# Row 173 successfully inserted!
#
# Row 174 successfully inserted!
#
# Row 175 successfully inserted!
#
# Row 176 successfully inserted!
#
# Row 177 successfully inserted!
#
# Row 178 successfully inserted!
#
# Row 179 successfully inserted!
#
# Row 180 successfully inserted!
#
# Row 181 successfully inserted!
#
# Row 182 successfully inserted!
#
# Row 183 successfully inserted!
#
# Row 184 successfully inserted!
#
# Row 185 successfully inserted!
#
# Row 186 successfully inserted!
#
# Row 187 successfully inserted!
#
# Row 188 successfully inserted!
#
# Row 189 successfully inserted!
#
# Row 190 successfully inserted!
#
# Row 191 successfully inserted!
#
# Row 192 successfully inserted!
#
# Row 193 successfully inserted!
#
# Row 194 successfully inserted!
#
# Row 195 successfully inserted!
#
# Row 196 successfully inserted!
#
# Row 197 successfully inserted!
#
# Row 198 successfully inserted!
#
# Row 199 successfully inserted!
#
# Row 200 successfully inserted!
#
# Row 201 successfully inserted!
#
# Row 202 successfully inserted!
#
# Row 203 successfully inserted!
#
# Row 204 successfully inserted!
#
# Row 205 successfully inserted!
#
# Row 206 successfully inserted!
#
# Row 207 successfully inserted!
#
# Row 208 successfully inserted!
#
# Row 209 successfully inserted!
#
# Row 210 successfully inserted!
#
# Row 211 successfully inserted!
#
# Row 212 successfully inserted!
#
# Row 213 successfully inserted!
#
# Row 214 successfully inserted!
#
# Row 215 successfully inserted!
#
# Row 216 successfully inserted!
#
# Row 217 successfully inserted!
#
# Row 218 successfully inserted!
#
# Row 219 successfully inserted!
#
# Row 220 successfully inserted!
#
# Row 221 successfully inserted!
#
# Row 222 successfully inserted!
#
# Row 223 successfully inserted!
#
# Row 224 successfully inserted!
#
# Row 225 successfully inserted!
#
# Row 226 successfully inserted!
#
# Row 227 successfully inserted!
#
# Row 228 successfully inserted!
#
# Row 229 successfully inserted!
#
# Row 230 successfully inserted!
#
# Row 231 successfully inserted!
#
# Row 232 successfully inserted!
#
# Row 233 successfully inserted!
#
# Row 234 successfully inserted!
#
# Row 235 successfully inserted!
#
# Row 236 successfully inserted!
#
# Row 237 successfully inserted!
#
# Row 238 successfully inserted!
#
# Row 239 successfully inserted!
#
# Row 240 successfully inserted!

# %% [markdown]
# ### Run Summary Stats to find meaningful insights

# %% [markdown]
# Find this vehicle's market average price by condition(New/Used/Certified Used)

# %%
file_name #print database name composed by user input
# Out:
# 'toyota_carmy_2019_2020_90021_50miles'

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Condition",
            "avgPrice": {"$avg": "$List Price"}
        }
    }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Used', 'avgPrice': 28144.82222222222}
# {'_id': 'Certified', 'avgPrice': 26398.786885245903}

# %% [markdown]
# Find this vehicle's average listing price by Seller Type

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Seller Type",
            "Average Price": {"$avg": "$List Price"}
        }
    }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Dealer', 'Average Price': 27702.87966804979}

# %% [markdown]
# Find how many dealers and how many private sellers who sell this vehicle

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Seller Type",
            "Count": {"$sum": 1}
        }
    }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Dealer', 'Count': 241}

# %% [markdown]
# Find this vehicle's market average price by exterior color (Limit to Top 10 by price)

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Exterior Color",
            "Average Price": {"$avg": "$List Price"}
        }
    },
    { "$sort": { "Average Price": -1 } },
    { "$limit": 10 }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Turbulence Gray', 'Average Price': 53591.0}
# {'_id': 'Absolute Zero', 'Average Price': 50995.0}
# {'_id': 'Yellow', 'Average Price': 49990.0}
# {'_id': 'Red', 'Average Price': 36594.666666666664}
# {'_id': 'Black', 'Average Price': 35938.6}
# {'_id': 'Magnetic Gray', 'Average Price': 34995.0}
# {'_id': 'Silver Sky Metallic', 'Average Price': 33411.25}
# {'_id': 'None', 'Average Price': 32991.0}
# {'_id': 'Ooh La La Rouge Mica', 'Average Price': 32000.0}
# {'_id': 'Magnetic Gray Metallic', 'Average Price': 31862.928571428572}

# %% [markdown]
# Find this vehicle's market average price by trim level

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Trim Level",
            "Average Price": {"$avg": "$List Price"}
        }
    },
    { "$sort": { "Average Price": -1 } }
])

for r in result:
    print(r)
# Out:
# {'_id': '4x4 CrewMax Limited', 'Average Price': 49990.0}
# {'_id': '4x4 CrewMax', 'Average Price': 49832.5}
# {'_id': 'CrewMax Platinum', 'Average Price': 49328.0}
# {'_id': 'TRD Pro', 'Average Price': 47842.0}
# {'_id': 'Limited Platinum Hybrid', 'Average Price': 42991.0}
# {'_id': '4x4 CrewMax SR5', 'Average Price': 42990.0}
# {'_id': '4WD', 'Average Price': 41980.0}
# {'_id': 'AWD XLE Hybrid', 'Average Price': 41952.0}
# {'_id': 'FWD Limited V6', 'Average Price': 41420.0}
# {'_id': '4x4 Double Cab Limited', 'Average Price': 41291.0}
# {'_id': '2WD CrewMax SR5', 'Average Price': 40439.0}
# {'_id': 'Limited Platinum', 'Average Price': 40222.0}
# {'_id': 'FWD XLE Hybrid', 'Average Price': 38998.0}
# {'_id': 'TRD Sport', 'Average Price': 38129.8}
# {'_id': 'TRD', 'Average Price': 38051.0}
# {'_id': 'XSE w/ TRD Package', 'Average Price': 37990.0}
# {'_id': 'SR5', 'Average Price': 37103.4}
# {'_id': '2WD SR5', 'Average Price': 36988.0}
# {'_id': 'Limited', 'Average Price': 35236.25}
# {'_id': 'TRD Off-Road', 'Average Price': 35042.833333333336}
# {'_id': 'AWD Limited Hybrid', 'Average Price': 34000.0}
# {'_id': 'FWD LE V6', 'Average Price': 33988.0}
# {'_id': 'SR5 Premium', 'Average Price': 33040.0}
# {'_id': 'Double Cab SR5', 'Average Price': 32991.0}
# {'_id': 'AWD XSE Hybrid', 'Average Price': 32990.0}
# {'_id': 'None', 'Average Price': 31522.958333333332}
# {'_id': '2WD Double Cab', 'Average Price': 31072.0}
# {'_id': 'XLE', 'Average Price': 30474.4375}
# {'_id': 'w/ SR5 Package', 'Average Price': 30350.733333333334}
# {'_id': 'AWD Adventure', 'Average Price': 30174.5}
# {'_id': 'FWD Limited', 'Average Price': 30138.0}
# {'_id': 'AWD', 'Average Price': 29883.0}
# {'_id': 'SR', 'Average Price': 29585.0}
# {'_id': 'FWD V6', 'Average Price': 29382.666666666668}
# {'_id': 'AWD XLE Premium', 'Average Price': 28999.0}
# {'_id': 'XSE w/ Navigation Package', 'Average Price': 27888.0}
# {'_id': 'XSE V6', 'Average Price': 27792.666666666668}
# {'_id': 'LE w/ Carpet Mat Package', 'Average Price': 27399.0}
# {'_id': 'TRD SE', 'Average Price': 27047.5}
# {'_id': 'AWD XLE w/ Carpet Mat Package', 'Average Price': 26850.0}
# {'_id': 'FWD LE', 'Average Price': 26027.2}
# {'_id': 'FWD XLE', 'Average Price': 25823.285714285714}
# {'_id': 'XSE', 'Average Price': 25789.571428571428}
# {'_id': 'Prime Advanced', 'Average Price': 24594.0}
# {'_id': 'Prime', 'Average Price': 24303.5}
# {'_id': 'SE Hybrid', 'Average Price': 23991.5}
# {'_id': 'FWD XLE w/ Convenience Package', 'Average Price': 23787.0}
# {'_id': 'FWD LE w/ Carpet Mat Package', 'Average Price': 22988.0}
# {'_id': 'Prime Premium', 'Average Price': 22487.666666666668}
# {'_id': 'Prime Plus', 'Average Price': 22149.5}
# {'_id': 'SE', 'Average Price': 19649.636363636364}
# {'_id': 'LE', 'Average Price': 17615.764705882353}
# {'_id': 'LE Sedan', 'Average Price': 17007.222222222223}
# {'_id': 'Hatchback', 'Average Price': 16889.0}
# {'_id': 'L', 'Average Price': 15534.666666666666}

# %% [markdown]
# Find this vehicle's market average price first by condition and second by trim level

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": 
                {"condition":"$Condition",
                 "trim":"$Trim Level"},
            "Average Price": {"$avg": "$List Price"}
        }
    },
    { "$sort": { "Average Price": -1 } }
])

for r in result:
    print(r)
# Out:
# {'_id': {'condition': 'Certified', 'trim': 'TRD Sport'}, 'Average Price': 51991.0}
# {'_id': {'condition': 'Used', 'trim': 'CrewMax Platinum'}, 'Average Price': 49990.0}
# {'_id': {'condition': 'Used', 'trim': '4x4 CrewMax Limited'}, 'Average Price': 49990.0}
# {'_id': {'condition': 'Certified', 'trim': '4x4 CrewMax'}, 'Average Price': 49832.5}
# {'_id': {'condition': 'Certified', 'trim': 'CrewMax Platinum'}, 'Average Price': 48666.0}
# {'_id': {'condition': 'Used', 'trim': 'TRD Pro'}, 'Average Price': 47842.0}
# {'_id': {'condition': 'Used', 'trim': '4x4 Double Cab Limited'}, 'Average Price': 43590.0}
# {'_id': {'condition': 'Certified', 'trim': 'Limited Platinum Hybrid'}, 'Average Price': 42991.0}
# {'_id': {'condition': 'Used', 'trim': '4x4 CrewMax SR5'}, 'Average Price': 42990.0}
# {'_id': {'condition': 'Used', 'trim': '4WD'}, 'Average Price': 41980.0}
# {'_id': {'condition': 'Certified', 'trim': 'AWD XLE Hybrid'}, 'Average Price': 41952.0}
# {'_id': {'condition': 'Certified', 'trim': 'FWD Limited V6'}, 'Average Price': 41888.0}
# {'_id': {'condition': 'Used', 'trim': '2WD CrewMax SR5'}, 'Average Price': 40990.0}
# {'_id': {'condition': 'Used', 'trim': 'FWD Limited V6'}, 'Average Price': 40952.0}
# {'_id': {'condition': 'Certified', 'trim': 'Limited Platinum'}, 'Average Price': 40222.0}
# {'_id': {'condition': 'Certified', 'trim': '2WD CrewMax SR5'}, 'Average Price': 39888.0}
# {'_id': {'condition': 'Used', 'trim': 'FWD XLE Hybrid'}, 'Average Price': 38998.0}
# {'_id': {'condition': 'Certified', 'trim': '4x4 Double Cab Limited'}, 'Average Price': 38992.0}
# {'_id': {'condition': 'Used', 'trim': 'TRD'}, 'Average Price': 38051.0}
# {'_id': {'condition': 'Used', 'trim': 'XSE w/ TRD Package'}, 'Average Price': 37990.0}
# {'_id': {'condition': 'Used', 'trim': 'SR5'}, 'Average Price': 37103.4}
# {'_id': {'condition': 'Used', 'trim': '2WD SR5'}, 'Average Price': 36988.0}
# {'_id': {'condition': 'Certified', 'trim': 'TRD Off-Road'}, 'Average Price': 36845.0}
# {'_id': {'condition': 'Used', 'trim': 'TRD Sport'}, 'Average Price': 36589.666666666664}
# {'_id': {'condition': 'Used', 'trim': 'Limited'}, 'Average Price': 35236.25}
# {'_id': {'condition': 'Used', 'trim': 'TRD Off-Road'}, 'Average Price': 34682.4}
# {'_id': {'condition': 'Used', 'trim': 'None'}, 'Average Price': 34379.73684210526}
# {'_id': {'condition': 'Used', 'trim': 'AWD Limited Hybrid'}, 'Average Price': 34000.0}
# {'_id': {'condition': 'Used', 'trim': 'FWD LE V6'}, 'Average Price': 33988.0}
# {'_id': {'condition': 'Used', 'trim': 'SR5 Premium'}, 'Average Price': 33040.0}
# {'_id': {'condition': 'Used', 'trim': 'Double Cab SR5'}, 'Average Price': 32991.0}
# {'_id': {'condition': 'Used', 'trim': 'AWD XSE Hybrid'}, 'Average Price': 32990.0}
# {'_id': {'condition': 'Certified', 'trim': 'XSE'}, 'Average Price': 31188.0}
# {'_id': {'condition': 'Used', 'trim': '2WD Double Cab'}, 'Average Price': 31072.0}
# {'_id': {'condition': 'Used', 'trim': 'XLE'}, 'Average Price': 31013.333333333332}
# {'_id': {'condition': 'Used', 'trim': 'w/ SR5 Package'}, 'Average Price': 30532.53846153846}
# {'_id': {'condition': 'Used', 'trim': 'AWD Adventure'}, 'Average Price': 30174.5}
# {'_id': {'condition': 'Used', 'trim': 'FWD Limited'}, 'Average Price': 30138.0}
# {'_id': {'condition': 'Used', 'trim': 'AWD'}, 'Average Price': 29883.0}
# {'_id': {'condition': 'Used', 'trim': 'SR'}, 'Average Price': 29585.0}
# {'_id': {'condition': 'Used', 'trim': 'FWD V6'}, 'Average Price': 29579.0}
# {'_id': {'condition': 'Certified', 'trim': 'w/ SR5 Package'}, 'Average Price': 29169.0}
# {'_id': {'condition': 'Used', 'trim': 'AWD XLE Premium'}, 'Average Price': 28999.0}
# {'_id': {'condition': 'Certified', 'trim': 'FWD V6'}, 'Average Price': 28990.0}
# {'_id': {'condition': 'Certified', 'trim': 'XLE'}, 'Average Price': 28857.75}
# {'_id': {'condition': 'Certified', 'trim': 'XSE w/ Navigation Package'}, 'Average Price': 27888.0}
# {'_id': {'condition': 'Used', 'trim': 'XSE V6'}, 'Average Price': 27792.666666666668}
# {'_id': {'condition': 'Certified', 'trim': 'FWD XLE'}, 'Average Price': 27488.0}
# {'_id': {'condition': 'Used', 'trim': 'LE w/ Carpet Mat Package'}, 'Average Price': 27399.0}
# {'_id': {'condition': 'Certified', 'trim': 'FWD LE'}, 'Average Price': 27112.0}
# {'_id': {'condition': 'Used', 'trim': 'TRD SE'}, 'Average Price': 27047.5}
# {'_id': {'condition': 'Used', 'trim': 'AWD XLE w/ Carpet Mat Package'}, 'Average Price': 26850.0}
# {'_id': {'condition': 'Used', 'trim': 'FWD XLE'}, 'Average Price': 25545.833333333332}
# {'_id': {'condition': 'Used', 'trim': 'Prime'}, 'Average Price': 24998.0}
# {'_id': {'condition': 'Certified', 'trim': 'Prime Advanced'}, 'Average Price': 24594.0}
# {'_id': {'condition': 'Certified', 'trim': 'SE Hybrid'}, 'Average Price': 24495.0}
# {'_id': {'condition': 'Certified', 'trim': 'FWD LE w/ Carpet Mat Package'}, 'Average Price': 23988.0}
# {'_id': {'condition': 'Used', 'trim': 'FWD XLE w/ Convenience Package'}, 'Average Price': 23787.0}
# {'_id': {'condition': 'Used', 'trim': 'XSE'}, 'Average Price': 23630.2}
# {'_id': {'condition': 'Certified', 'trim': 'Prime'}, 'Average Price': 23609.0}
# {'_id': {'condition': 'Used', 'trim': 'SE Hybrid'}, 'Average Price': 23488.0}
# {'_id': {'condition': 'Certified', 'trim': 'Prime Premium'}, 'Average Price': 23285.0}
# {'_id': {'condition': 'Used', 'trim': 'Prime Plus'}, 'Average Price': 22149.5}
# {'_id': {'condition': 'Used', 'trim': 'Prime Premium'}, 'Average Price': 22089.0}
# {'_id': {'condition': 'Used', 'trim': 'FWD LE w/ Carpet Mat Package'}, 'Average Price': 21988.0}
# {'_id': {'condition': 'Used', 'trim': 'FWD LE'}, 'Average Price': 21688.0}
# {'_id': {'condition': 'Certified', 'trim': 'None'}, 'Average Price': 20667.2}
# {'_id': {'condition': 'Certified', 'trim': 'LE'}, 'Average Price': 20070.0}
# {'_id': {'condition': 'Certified', 'trim': 'SE'}, 'Average Price': 19966.333333333332}
# {'_id': {'condition': 'Used', 'trim': 'SE'}, 'Average Price': 19468.666666666668}
# {'_id': {'condition': 'Used', 'trim': 'Hatchback'}, 'Average Price': 17990.0}
# {'_id': {'condition': 'Certified', 'trim': 'LE Sedan'}, 'Average Price': 17968.6}
# {'_id': {'condition': 'Used', 'trim': 'LE Sedan'}, 'Average Price': 16637.46153846154}
# {'_id': {'condition': 'Used', 'trim': 'LE'}, 'Average Price': 16593.166666666668}
# {'_id': {'condition': 'Used', 'trim': 'L'}, 'Average Price': 15956.25}
# {'_id': {'condition': 'Certified', 'trim': 'Hatchback'}, 'Average Price': 15788.0}
# {'_id': {'condition': 'Certified', 'trim': 'L'}, 'Average Price': 14691.5}

# %% [markdown]
# Find what exterior colors are popular in the market

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Exterior Color",
            "Count": {"$sum": 1}
        }
    },
    { "$sort": { "Count": -1 } }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Super White', 'Count': 24}
# {'_id': 'Midnight Black Metallic', 'Count': 22}
# {'_id': 'Silver', 'Count': 20}
# {'_id': 'White', 'Count': 19}
# {'_id': 'Gray', 'Count': 16}
# {'_id': 'Magnetic Gray Metallic', 'Count': 14}
# {'_id': 'Blizzard Pearl', 'Count': 13}
# {'_id': 'Silver Sky Metallic', 'Count': 12}
# {'_id': 'Black', 'Count': 10}
# {'_id': 'Predawn Gray Mica', 'Count': 10}
# {'_id': 'Black Sand Pearl', 'Count': 10}
# {'_id': 'Classic Silver Metallic', 'Count': 7}
# {'_id': 'Red', 'Count': 6}
# {'_id': 'Celestial Silver Metallic', 'Count': 5}
# {'_id': 'Blue', 'Count': 5}
# {'_id': 'Barcelona Red Metallic', 'Count': 4}
# {'_id': 'Wind Chill Pearl', 'Count': 3}
# {'_id': 'Ruby Flare Pearl', 'Count': 3}
# {'_id': 'Blueprint', 'Count': 3}
# {'_id': 'Bronze Oxide', 'Count': 2}
# {'_id': 'Frost', 'Count': 2}
# {'_id': 'Raven', 'Count': 2}
# {'_id': 'Celestite', 'Count': 2}
# {'_id': 'Predawn Gray', 'Count': 2}
# {'_id': 'Slate Metallic', 'Count': 2}
# {'_id': 'Blue Flame', 'Count': 1}
# {'_id': 'Supersonic Red', 'Count': 1}
# {'_id': 'Blue Flame W/Black Roof', 'Count': 1}
# {'_id': 'Blue Streak Metallic', 'Count': 1}
# {'_id': 'Blue Magnetism', 'Count': 1}
# {'_id': 'Wind Chill Pearl/Midnight Black Metallic', 'Count': 1}
# {'_id': 'Nordic White', 'Count': 1}
# {'_id': 'Galactic Aqua Mica', 'Count': 1}
# {'_id': 'Turbulence Gray', 'Count': 1}
# {'_id': 'Parisian Night Pearl', 'Count': 1}
# {'_id': 'Falcon Gray Metallic', 'Count': 1}
# {'_id': 'Hypersonic Red', 'Count': 1}
# {'_id': 'Yellow', 'Count': 1}
# {'_id': 'Ooh La La Rouge Mica', 'Count': 1}
# {'_id': 'Magnetic Gray', 'Count': 1}
# {'_id': 'Ruby Flare Pearl W/Black Roof', 'Count': 1}
# {'_id': 'Graphite', 'Count': 1}
# {'_id': 'Sapphire', 'Count': 1}
# {'_id': 'Absolute Zero', 'Count': 1}
# {'_id': 'Stealth', 'Count': 1}
# {'_id': 'Salsa Red Pearl', 'Count': 1}
# {'_id': 'Silver Knockout Metallic W/Black Roof', 'Count': 1}
# {'_id': 'None', 'Count': 1}

# %% [markdown]
# Find this vehicle's average listing price from dealers that have ratings higher than 4.0

# %%
result = mycollection.aggregate([
    { "$match": { "Seller Rating": { "$gte": 4.0} } },
    {
        "$group": {
            "_id": "4.0+",
            "Average Price": {"$avg": "$List Price"}
        }
    },
    { "$sort": { "Average Price": -1 } }
])

for r in result:
    print(r)
# Out:
# {'_id': '4.0+', 'Average Price': 26352.32338308458}

# %% [markdown]
# Find dealer's average rating

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "Dealer Rating",
            "Average Rating": {"$avg": "$Seller Rating"}
        }
    },
    { "$sort": { "Average Rating": -1 } }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Dealer Rating', 'Average Rating': 4.467149758454107}

# %% [markdown]
# Find the seller contact information who has lowest listing price

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": {
                "Seller Name":"$Seller Name",
                "Seller Phone Number":"$Seller Phone Number"
            },
            "Min Price": {"$min": "$List Price"}
        }
    },
    { "$sort": { "Min Price": 1 } }
])

for r in result:
    print(r)
    break
# Out:
# {'_id': {'Seller Name': 'DCH Toyota of Torrance', 'Seller Phone Number': '(424) 757-6069'}, 'Min Price': 12388}
