# %% [markdown]
# # Chloe Wang, Qihan Guan, Michael Harris #
# ### BAX-422 Group 5 ###
# ### March 9, 2021 ###

# %%
pip install pyzipcode
# Out:
# Collecting pyzipcode
#   Downloading pyzipcode-3.0.1.tar.gz (1.9 MB)
# Building wheels for collected packages: pyzipcode
#   Building wheel for pyzipcode (setup.py): started
#   Building wheel for pyzipcode (setup.py): finished with status 'done'
#   Created wheel for pyzipcode: filename=pyzipcode-3.0.1-py3-none-any.whl size=1932419 sha256=37d9db666e6db5b2b6a71ac09875e78788eff76a6ee3eb7e22c1bc4658a52904
#   Stored in directory: c:\users\dvcgu\appdata\local\pip\cache\wheels\f6\01\8e\7424c7e867eb5db7bb9531b09b4d968f23e5ac45ec5e7c3cb3
# Successfully built pyzipcode
# Installing collected packages: pyzipcode
# Successfully installed pyzipcode-3.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import packages
from bs4 import BeautifulSoup, Tag
from urllib.request import Request, urlopen
from urllib.request import urlopen
import requests
import time
import warnings
import requests
import os
import json
import re
import codecs
import urllib.request, urllib.error, urllib.parse
import shutil
from lxml import html
from time import sleep
from itertools import zip_longest
from pyzipcode import ZipCodeDatabase
import pandas as pd
import numpy as np

# %%
# Ask Input for Car make.
make = str(input("Enter Make(Press enter directly to omit): ")).lower()

# Ask Input for Model
model = str(input("Enter Model(Press enter directly to omit): ")).lower()

# Ask Input for Minimum Year
min_year = ''
while True: 
  year1 = int(input("Please enter vehicle minimum year: (1981-2021): ")) 
  min_year = str(year1)
  if year1 not in range(1981,2022):
    print("**Please enter a valid year**")
    continue
  else:
    break


# Ask Input for Maximum Year
max_year = ''
while True: 
  year2 = int(input("Please enter vehicle maximum year: (1981-2021): ")) 
  max_year = str(year2)
  if year2 not in range(1981,2022):
    print("**Please enter a valid year**")
    continue
  elif year2 < int(min_year):
    print("**Maximum year cannot be older than minimum year**")
    continue
  else:
    break

# Ask Input for Zip Code
url_geo=''
while True: 
  zipcode = str(input("Please enter your 5-digit Zip Code: ")) 
  zipdb = ZipCodeDatabase()
  try: 
    geoinfo = zipdb[zipcode]
    url_geo = str(geoinfo.city).lower().replace(" ","-") +"-"+str(geoinfo.state).lower()+"-"+str(zipcode)
  except: 
    print("**Please enter a valid zipcode**") 
    continue
  else:
    break
print(url_geo)
# Ask Input for Radius
radius=''
while True: 
  radius = str(input("Please enter your search radius in miles (10/25/50/75/100/200/300/400/500/ 0 for any): ")) 
  if radius not in ['10','25','50','75','100','200','300','400','500','0']:
    print("**Please enter a valid radius**")
    continue
  else:
    break
# Out:
# Enter Make(Press enter directly to omit): toyota
# Enter Model(Press enter directly to omit): camry
# Please enter vehicle minimum year: (1981-2021): 2019
# Please enter vehicle maximum year: (1981-2021): 2020
# Please enter your 5-digit Zip Code: 50
# **Please enter a valid zipcode**
# Please enter your 5-digit Zip Code: 77002
# houston-tx-77002
# Please enter your search radius in miles (10/25/50/75/100/200/300/400/500/ 0 for any): 50

# %%
# Compose the URL based on user input. Set to 100 items per page to miminze get requests
url = str("https://www.autotrader.com/cars-for-sale/all-cars/"+make+"/"+model+"/"+url_geo+"?dma=&searchRadius="+
radius+"&location=&marketExtension=include&startYear="+min_year+"&endYear="+max_year+"&isNewSearch=true&showAccelerateBanner=false&sortBy=relevance&numRecords=100")

print(url)
# Out:
# https://www.autotrader.com/cars-for-sale/all-cars/toyota/camry/houston-tx-77002?dma=&searchRadius=50&location=&marketExtension=include&startYear=2019&endYear=2020&isNewSearch=true&showAccelerateBanner=false&sortBy=relevance&numRecords=100

# %% [markdown]
# ### Save all the listed vehicle URLs under the user input criteria

# %%
# Scrape All URLs from Search:
header = ({'User-Agent':'Mozilla/5.0'}) 

# Initialize a list to save the item urls
url_list = []

# Loop thorugh all the pages available 
i = 0 # set a intial counter 0
while True:
    URL = url + '&firstRecord=' + str(i*100) #Autotrader uses a multiplier of num_records_per_page to navigate to different pages
    response = requests.get(URL, headers = header)
    soup = BeautifulSoup(response.content, 'html.parser')
    pagebuttons = soup.find_all('li', {'class':'active'})
    out_of_bound = True
    
    #Check in page number out-of-bound
    for buttons in pagebuttons:
        if(len(buttons.find_all('a', {'role':'button'}))!=0):
            out_of_bound = False
    
    if out_of_bound == True: # Stop if page number out-of-bound
        break
    #else, scrape url of each listed vehicle for sale
    else:
        items = soup.findAll('div',{"class":"display-flex justify-content-between"})
        for item in items:
            a = item.find("a")
            if not a:
                continue
            url_simplify = 'https://www.autotrader.com' + a['href']
            url_list.append(url_simplify + "\n")
            print(url_simplify)
        #set a time lapse
        time.sleep(4)
        
    #increment counter
    i = i+1
# Out:
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576142368&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dtrue&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=alpha
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578030578&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&clickType=spotlight
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579422228&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&clickType=spotlight
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579378834&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579022326&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579022325&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578943056&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=565996249&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576349731&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&clickType=spotlight
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=574145071&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578498405&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576223685&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577475189&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576456799&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577258395&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578575265&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578997979&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=572093421&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578503608&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577738722&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577364705&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579400423&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577500233&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578665063&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=572214019&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579378833&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578705575&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578619768&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575483661&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579118313&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578998710&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577399839&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577399841&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=570889222&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577847796&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577502961&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577719344&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577847793&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577847790&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577475178&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576223688&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576223664&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578619762&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578261826&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578198145&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578746390&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578301128&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576456381&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576349731&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=574397167&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575334430&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578664751&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578664750&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578664747&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579136844&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576142368&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=563964865&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=562877705&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=562877696&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=563885683&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575236933&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576573190&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578619785&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578619784&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578619766&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=573436865&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577876747&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575382287&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578030306&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576604262&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578030578&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578425967&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=576866338&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577811384&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D0%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=0&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# ...
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575284354&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578885858&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=555011311&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=555011230&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=563864469&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579450021&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=566146339&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579401205&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577206204&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579397161&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579140727&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577667487&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578926933&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575994466&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578509465&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578509522&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575104345&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=534047765&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=575712333&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578357232&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=577267474&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578357231&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=578284341&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing
# https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=579535353&zip=77002&referrer=%2Fcars-for-sale%2Fsearchresults.xhtml%3Fzip%3D77002%26city%3DHouston%26startYear%3D2019%26numRecords%3D100%26incremental%3Dall%26endYear%3D2020%26modelCodeList%3DCAMRY%26makeCodeList%3DTOYOTA%26sortBy%3Drelevance%26location%3D%255Bobject%2BObject%255D%26state%3DTX%26firstRecord%3D100%26marketExtension%3Dinclude%26relevanceConfig%3Ddefault%26searchRadius%3D50%26isNewSearch%3Dfalse&startYear=2019&numRecords=100&firstRecord=100&endYear=2020&modelCodeList=CAMRY&makeCodeList=TOYOTA&searchRadius=50&makeCode1=TOYOTA&modelCode1=CAMRY&clickType=listing

# %%
#Check the total number of URLs saved
len(url_list)
# Out:
# 154

# %% [markdown]
# ### Open all the URLs and save the listing vehicles' pages in a directory

# %%
#Compose a filename based on the user input
file_name = make+'_'+model+'_'+min_year+'_'+max_year+'_'+str(zipcode)+'_'+str(radius)+'miles'

#Write all listed vehicle's url to file_name.txt
with open(os.getcwd()+'/'+file_name+'.txt', 'w+') as filehandle:
    for item_url in url_list:
        filehandle.write('%s' % item_url)

# %%
#read the txt file and save the listed vehicles' pages as html files
cars = open(os.getcwd()+'/'+file_name+'.txt', 'r').read().split('\n')
headers = {'User-Agent':'Mozilla/5.0'}  

#create path for 'file_name' folder
path = os.path.join(os.getcwd() , file_name)
if not os.path.exists(path):
    os.makedirs(path)

try:
    #Download each of the pages(URLs) into the folder 'file_name'
    for URL in cars[0:243]:
        listing_id = re.search(r'\?listingId=([0-9]+)&', URL).group(1) #Use listing ID as name for each html file
        page = requests.get(URL, headers=headers) 
        with open(os.path.join(path, str(listing_id)+'.html'), 'w+', encoding="utf-8") as filehandle:
            filehandle.write(page.text)

        #put a 3 sec pause between queries
        time.sleep(3)
except:
    print('Problem with connection...')
# Out:
# Problem with connection...

# %%
#Check how many files saved successfully
list = os.listdir(path) 
print(len(list))
# Out:
# 146

# %% [markdown]
# ### Open each saved html file and save the data we want in a pd dataframe
# For each listed vehicle, we will save the following information:
#
# Listing ID, Vehicle Condition, Year, Make, Model, Trim Level, List Price, Mileage, Transimission, Drivetrain(FWD/RWD/AWD), Exterior Color, Interior Color, Engine Type, City MPG, Highway Mpg, Seller Type(Private or Dealer), Seller Name, Seller Rating, Seller Number of Reviews, Seller Street Address, Seller City, Seller State, Seller Zipcode, Seller Phone Number

# %%
#initialize a data frame to save 

vehicle_info = pd.DataFrame(columns=['Listing ID','Condition', 'Year', 'Make', 'Model','Trim Level','List Price','Mileage',
                                    'Exterior Color', 'Interior Color','Engine Type','Transmission','Drivetrain(FWD/RWD/AWD)', 
                                     'City MPG', 'Highway MPG', 'Seller Type', 'Seller Name','Seller Rating',
                                    'Number of Reviews','Seller Street Address', 'Seller City','Seller State',
                                     'Seller Zipcode','Seller Phone Number'])

for i in range(0, len(list)):
    try:
        page = list[i]
        listing_id = re.search(r'([0-9]+)\.html',list[i]).group(1) #Get Listing ID
        page_file = open(path + '\\' + page, 'r', encoding="utf-8").read() 
        soup = BeautifulSoup(page_file, 'html.parser')

        #selector command for Vehicle Condition
        try:
            title_raw = soup.find('h1', class_ ='text-bold text-size-400 text-size-sm-700').text
            condition = re.search(r'([UCN][a-z]+) ([0-9]{4}) ([A-Za-z]+) ([A-Za-z0-9]+)',title_raw).group(1)
        except:
            condition = None
            
        #selector command for Vehicle Year
        try:
            year = re.search(r'([UCN][a-z]+) ([0-9]{4}) ([A-Za-z]+) ([A-Za-z0-9]+)',title_raw).group(2)
        except:
            year = None

        #selector command for Vehicle Make
        try:
            make = re.search(r'([UCN][a-z]+) ([0-9]{4}) ([A-Za-z]+) ([A-Za-z0-9]+)',title_raw).group(3)
        except:
            make = None
        
        #selector command for Vehicle Model
        try:
            model = re.search(r'([UCN][a-z]+) ([0-9]{4}) ([A-Za-z]+) ([A-Za-z0-9]+)',title_raw).group(4)
        except:
            model = None
        
        #selector command for Vehicle Trim Level
        try:
            trim = re.search(r'([UCN][a-z]+) ([0-9]{4}) ([A-Za-z]+) ([A-Za-z0-9]+) (.+)',title_raw).group(5)
        except:
            trim = None
        
        #selector command for List Price
        #In most cases, a net price will be displayed
        try:
            price = int(soup.find('span',{'class':'first-price'}).text.replace(',',''))
        except:#For new vehicles, some of them will display only the MSRP as price
            try:
                price_raw = soup.find('span', {'class':'padding-left-2 padding-bottom-1 text-normal second-price'}).find('span', {'class':'text-bold'}).text
                price = int(price_raw.replace(',',''))  
            except:
                price = None
        
        #selector command for Vehicle Mileage
        try:
            #find the element following the mileage icon
            m = soup.find('div', {'style':'background:url(https://www.autotrader.com/content/dam/autotrader/findcar/vdp/specifications/all_spec_icons.svg) -191px -74px;height:25px;width:30px'})
            mileage_raw = re.search(r'(.+) miles',m.parent.find_next_sibling('div').text).group(1)
            mileage = int(mileage_raw.replace(',',''))
        except:
            mileage = None
        
        #selector command for Exterior Color
        try:
            #find the element following the exterior color icon
            excol = soup.find_all('div', {'class':'swatch'})[0]
            extcolor = re.search(r'(.+) Exterior',excol.parent.parent.nextSibling.text).group(1)
        except:
            extcolor = None
        
        #selector command for Interior Color
        try:
            #find the element following the interior color icon
            incol = soup.find_all('div', {'class':'swatch'})[1]
            intcolor = re.search(r'(.+) Interior',incol.parent.parent.nextSibling.text).group(1)
        except:
            intcolor = None
        
        #selector command for Engine Type
        try:
            eng = soup.find('div', {'aria-label':"ENGINE_DESCRIPTION"})
            engine = eng.parent.find_next_sibling('div').text
        except:
            engine = None
        
        #selector command for Transmission
        try:
            trans = soup.find('div', {'aria-label':"TRANSMISSION"})
            transmission = trans.parent.find_next_sibling('div').text
        except:
            transmission = None
        
        #selector command for Drivetrain
        try:
            drive = soup.find('div', {'aria-label':"DRIVE TYPE"})
            drivetrain = drive.parent.find_next_sibling('div').text
        except:
            drivetrain = None
            
        #selector command for City MPG
        try:
            mpg = soup.find('div', {'aria-label':"MPG"}).parent.find_next_sibling('div').text
            city_mpg = re.search(r'([0-9]+) City / ([0-9]+) Highway',mpg).group(1)
        except:
            city_mpg = None
            
        #selector command for Highway MPG
        try:
            mpg = soup.find('div', {'aria-label':"MPG"}).parent.find_next_sibling('div').text
            highway_mpg = re.search(r'([0-9]+) City / ([0-9]+) Highway',mpg).group(2)
        except:
            highway_mpg = None
            
        #Get Seller's type (either private seller or dealer)
        #if find the h2 class for 'private seller' heading, then it's private seller
        if(len(soup.find_all('h2', {'class':'text-bold padding-bottom-3'}))!=0):
            seller_type = 'Private Seller'
        #otherwise, the seller is a dealer    
        else:
            seller_type = 'Dealer'
            
        #Get Seller Name
        if seller_type == 'Dealer':
            try:
                seller_name = soup.find('h2', {'class':"text-left text-bold text-size-20 display-inline"}).text
            except:
                try:
                    seller_name = soup.find('h2', {'class':"text-left text-bold text-size-20"}).text
                except:
                    seller_name = None
        else:
            seller_name = None #Set to 'None' for private sellers because Not Applicable
            
        #Get Seller Rating
        if seller_type == 'Dealer':
            try:
                seller_rating = float(soup.find('span', {'class': "text-bold text-subdued"}).text)
            except:
                seller_rating = None
        else:
            seller_rating = None #Set to 'None' for private sellers because Not Applicable
        
        #Get Number of Reviews for the Seller
        if seller_type == 'Dealer':
            try:
                num_reviews_raw = soup.find('a', {'class': "cursor-pointer padding-left-1"}).text
                num_reviews = int(re.search(r'([0-9]+)', num_reviews_raw).group(1))
            except:
                num_reviews = 0 
        else:
            num_reviews = None #Set to 'None' for private sellers because Not Applicable
        
        #Get Seller Street Address
        addrs = soup.find_all('div', {'data-cmp': "address"})
        address = ''
        for addr in addrs:
            for line in addr:
                address = address + line.text
        try:
            seller_street = re.search(r'([0-9]+ [A-Z].+), [A-Za-z\s]+, ', address).group(1)
        except:
            seller_street = None
            
        #Get Seller City
        try:
            seller_city = re.search(r'(.*,)?\s?(.*), [A-Z]{2} [0-9]{5}', address).group(2)
        except:
            seller_city = None  
            
        #Get Seller State
        try:
            seller_state = re.search(r', ([A-Z]{2}) ([0-9]{5})', address).group(1)
        except:
            seller_state = None
        
        #Get Seller Zipcode
        try:
            seller_zip = re.search(r', ([A-Z]{2}) ([0-9]{5})', address).group(2)
        except:
            seller_zip = None
        
        #Get Seller Phone Number
        try:
            seller_phone = soup.find('span', {'data-cmp':'phoneNumber'}).text
        except:
            seller_phone = None
            
        #save this iteration's result to the i-th row of the dataframe
        vehicle_info.loc[i] = [listing_id, condition, year, make, model, trim, price, mileage, extcolor, intcolor, engine, transmission, drivetrain, city_mpg, 
                       highway_mpg, seller_type, seller_name, seller_rating, num_reviews, seller_street, seller_city, seller_state,
                       seller_zip, seller_phone]

           
    except:
        print('Error with: ' + page)

# %% [markdown]
# ### View Saved Data

# %%
vehicle_info
# Out:
#     Listing ID Condition  Year    Make  Model Trim Level List Price Mileage  \
# 0    534047765       New  2020  Toyota  Camry        XLE      36596       0
# 1    555011230       New  2020  Toyota  Camry  LE Hybrid      27690       5
# 2    555011311       New  2020  Toyota  Camry  LE Hybrid      27690    3000
# 3    562877696      Used  2019  Toyota  Camry         LE      18991   32835
# 4    562877698      Used  2019  Toyota  Camry         LE      18991   22028
# ..         ...       ...   ...     ...    ...        ...        ...     ...
# 141  579469395      Used  2019  Toyota  Camry         SE      20990   10946
# 142  579469404      Used  2020  Toyota  Camry    XSE AWD      29780    7529
# 143  579522957      Used  2019  Toyota  Camry          L      19989   26915
# 144  579534433      Used  2020  Toyota  Camry         SE      21988   15677
# 145  579535353      Used  2020  Toyota  Camry        XSE       None   11887
#
#                 Exterior Color Interior Color  ... Highway MPG Seller Type  \
# 0                  Super White           None  ...          41      Dealer
# 1         Blue Streak Metallic          Black  ...          53      Dealer
# 2         Blue Streak Metallic           None  ...          53      Dealer
# 3                       Silver            Ash  ...          41      Dealer
# 4                       Silver           None  ...          41      Dealer
# ..                         ...            ...  ...         ...         ...
# 141                        Red          Black  ...          41      Dealer
# 142          Predawn Gray Mica          Black  ...        None      Dealer
# 143  Celestial Silver Metallic            Ash  ...          41      Dealer
# 144                       Blue          Black  ...          41      Dealer
# 145                       None           None  ...          41      Dealer
#
#                                            Seller Name Seller Rating  \
# 0                                  Mike Calvert Toyota           4.3
# 1                               Sterling McCall Toyota           4.7
# 2                               Sterling McCall Toyota           4.7
# 3                               Fred Haas Toyota World           4.6
# 4                               Fred Haas Toyota World           4.6
# ..                                                 ...           ...
# 141  Vroom - Get It Delivered Nationwide, Contact-Free          None
# 142  Vroom - Get It Delivered Nationwide, Contact-Free          None
# 143                                          Cook Ford           4.7
# 144                                Mike Calvert Toyota           4.4
# 145                                   John Eagle Acura           4.6
#
#     Number of Reviews   Seller Street Address Seller City Seller State  \
# 0                2707           2333 S LOOP W     HOUSTON           TX
# 1                9709  9400 Southwest Freeway     Houston           TX
# 2                9709  9400 Southwest Freeway     Houston           TX
# 3                4893        20400 I-45 North      Spring           TX
# 4                4893        20400 I-45 North      Spring           TX
# ..                ...                     ...         ...          ...
# 141                 0                    None        None         None
# 142                 0                    None        None         None
# 143              1173         2600 Palmer Hwy  Texas City           TX
# 144              2715           2333 S LOOP W     HOUSTON           TX
# 145              2798      16015 Katy Freeway     Houston           TX
#
#     Seller Zipcode Seller Phone Number
# 0            77054      (832) 914-1850
# 1            77074      (832) 941-1230
# 2            77074      (832) 941-1230
# 3            77373      (281) 907-8042
# 4            77373      (281) 907-8042
# ..             ...                 ...
# 141           None    1 (844) 648-6316
# 142           None    1 (844) 648-6316
# 143          77590      (409) 359-4090
# 144          77054      (832) 650-0421
# 145          77094      (832) 900-7848
#
# [146 rows x 24 columns]

# %% [markdown]
# ### Save Data to MongoDB

# %%
#Connect to MongoDB
import pymongo
from pymongo import MongoClient

client = MongoClient('localhost', 27017)

db = client[file_name] #use the user input criteria to compose a database name
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'toyota_camry_2019_2020_77002_50miles')

# %% [markdown]
# Save data from dataframe to MongoDB collection row by row:

# %%
#Show database name
print(file_name)
mycollection = db[file_name]
print(mycollection)
# Out:
# toyota_camry_2019_2020_77002_50miles
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'toyota_camry_2019_2020_77002_50miles'), 'toyota_camry_2019_2020_77002_50miles')

# %%
for i in vehicle_info.index:
    #If seller is a dealer, insert all info
    if vehicle_info['Seller Type'][i] == 'Dealer':
        listing_id = int(vehicle_info['Listing ID'][i])
        try:
            Condition = str(vehicle_info['Condition'][i])
        except:
            Condition = None
        try:
            Year = int(vehicle_info['Year'][i])
        except:
            Year = None
        try:
            Make = str(vehicle_info['Make'][i])
        except:
            Make = None
        try:
            Model = str(vehicle_info['Model'][i])
        except:
            Model = None
        try:
            TrimLevel = str(vehicle_info['Trim Level'][i])
        except:
            TrimLevel = None
        try:
            ListPrice = int(vehicle_info['List Price'][i])
        except:
            ListPrice = None
        try:
            Mileage = int(vehicle_info['Mileage'][i])
        except:
            Mileage = None
        try:
            ExteriorColor = str(vehicle_info['Exterior Color'][i])
        except:
            ExteriorColor = None
        try:
            InteriorColor = str(vehicle_info['Interior Color'][i])
        except:
            InteriorColor = None
        try:
            EngineType = str(vehicle_info['Engine Type'][i])
        except:
            EngineType = None
        try:
            Transmission = str(vehicle_info['Transmission'][i])
        except:
            Transmission = None
        try:
            Drivetrain = str(vehicle_info['Drivetrain(FWD/RWD/AWD)'][i])
        except:
            Drivetrain = None
        try:
            CityMPG = int(vehicle_info['City MPG'][i])
        except:
            CityMPG = None
        try:
            HighwayMPG = int(vehicle_info['Highway MPG'][i])
        except:
            HighwayMPG = None
        SellerType = str(vehicle_info['Seller Type'][i])
        try:
            SellerName = str(vehicle_info['Seller Name'][i])
        except:
            SellerName = None
        try:
            SellerRating = float(vehicle_info['Seller Rating'][i])
        except:
            SellerRating = None
        try:
            NumberofReviews = int(vehicle_info['Number of Reviews'][i])
        except:
            NumberofReviews = None
        try:
            SellerStreetAddress = str(vehicle_info['Seller Street Address'][i])
        except:
            SellerStreetAddress = None
        try:
            SellerCity = str(vehicle_info['Seller City'][i])
        except:
            SellerCity = None
        try:
            SellerState = str(vehicle_info['Seller State'][i])
        except:
            SellerState = None
        try:
            SellerZipcode = str(vehicle_info['Seller Zipcode'][i])
        except:
            SellerZipcode = None
        try:
            SellerPhoneNumber = str(vehicle_info['Seller Phone Number'][i])
        except:
            SellerPhoneNumber = None
        
        mydict = {
            '_id' : listing_id,
            'Condition': Condition,
            'Year': Year,
            'Make': Make,
            'Model': Model,
            'Trim Level': TrimLevel,
            'List Price': ListPrice,
            'Mileage': Mileage,
            'Exterior Color': ExteriorColor,
            'Interior Color': InteriorColor,
            'Engine Type': EngineType,
            'Transmission': Transmission,
            'Drivetrain': Drivetrain,
            'City MPG': CityMPG,
            'Highway MPG': HighwayMPG,
            'Seller Type': SellerType,
            'Seller Name': SellerName,
            'Seller Rating': SellerRating,
            'Number of Reviews': NumberofReviews,
            'Seller Street Address': SellerStreetAddress,
            'Seller City': SellerCity,
            'Seller State': SellerState,
            'Seller Zipcode': SellerZipcode,
            'Seller Phone Number': SellerPhoneNumber 
        }
        
        #insert this listed vehicle's data to MongoDB database 
        mycollection.insert_one(mydict)
    
    #If seller is a private seller, do not save Seller Name, Seller Rating or Number of Reviews
    else:
        listing_id = int(vehicle_info['Listing ID'][i])
        try:
            Condition = str(vehicle_info['Condition'][i])
        except:
            Condition = None
        try:
            Year = int(vehicle_info['Year'][i])
        except:
            Year = None
        try:
            Make = str(vehicle_info['Make'][i])
        except:
            Make = None
        try:
            Model = str(vehicle_info['Model'][i])
        except:
            Model = None
        try:
            TrimLevel = str(vehicle_info['Trim Level'][i])
        except:
            TrimLevel = None
        try:
            ListPrice = int(vehicle_info['List Price'][i])
        except:
            ListPrice = None
        try:
            Mileage = int(vehicle_info['Mileage'][i])
        except:
            Mileage = None
        try:
            ExteriorColor = str(vehicle_info['Exterior Color'][i])
        except:
            ExteriorColor = None
        try:
            InteriorColor = str(vehicle_info['Interior Color'][i])
        except:
            InteriorColor = None
        try:
            EngineType = str(vehicle_info['Engine Type'][i])
        except:
            EngineType = None
        try:
            Transmission = str(vehicle_info['Transmission'][i])
        except:
            Transmission = None
        try:
            Drivetrain = str(vehicle_info['Drivetrain(FWD/RWD/AWD)'][i])
        except:
            Drivetrain = None
        try:
            CityMPG = int(vehicle_info['City MPG'][i])
        except:
            CityMPG = None
        try:
            HighwayMPG = int(vehicle_info['Highway MPG'][i])
        except:
            HighwayMPG = None
        SellerType = str(vehicle_info['Seller Type'][i])
        try:
            SellerStreetAddress = str(vehicle_info['Seller Street Address'][i])
        except:
            SellerStreetAddress = None
        try:
            SellerCity = str(vehicle_info['Seller City'][i])
        except:
            SellerCity = None
        try:
            SellerState = str(vehicle_info['Seller State'][i])
        except:
            SellerState = None
        try:
            SellerZipcode = str(vehicle_info['Seller Zipcode'][i])
        except:
            SellerZipcode = None
        try:
            SellerPhoneNumber = str(vehicle_info['Seller Phone Number'][i])
        except:
            SellerPhoneNumber = None
        
        mydict = {
            '_id' : listing_id,
            'Condition': Condition,
            'Year': Year,
            'Make': Make,
            'Model': Model,
            'Trim Level': TrimLevel,
            'List Price': ListPrice,
            'Mileage': Mileage,
            'Exterior Color': ExteriorColor,
            'Interior Color': InteriorColor,
            'Engine Type': EngineType,
            'Transmission': Transmission,
            'Drivetrain': Drivetrain,
            'City MPG': CityMPG,
            'Highway MPG': HighwayMPG,
            'Seller Type': SellerType,
            'Seller Street Address': SellerStreetAddress,
            'Seller City': SellerCity,
            'Seller State': SellerState,
            'Seller Zipcode': SellerZipcode,
            'Seller Phone Number': SellerPhoneNumber 
        }
        
        #insert this listed vehicle's data to MongoDB database 
        mycollection.insert_one(mydict)
        
    print('Row '+str(i)+' successfully inserted!\n')
# Out:
# Row 0 successfully inserted!
#
# Row 1 successfully inserted!
#
# Row 2 successfully inserted!
#
# Row 3 successfully inserted!
#
# Row 4 successfully inserted!
#
# Row 5 successfully inserted!
#
# Row 6 successfully inserted!
#
# Row 7 successfully inserted!
#
# Row 8 successfully inserted!
#
# Row 9 successfully inserted!
#
# Row 10 successfully inserted!
#
# Row 11 successfully inserted!
#
# Row 12 successfully inserted!
#
# Row 13 successfully inserted!
#
# Row 14 successfully inserted!
#
# Row 15 successfully inserted!
#
# Row 16 successfully inserted!
#
# Row 17 successfully inserted!
#
# Row 18 successfully inserted!
#
# Row 19 successfully inserted!
#
# Row 20 successfully inserted!
#
# Row 21 successfully inserted!
#
# Row 22 successfully inserted!
#
# Row 23 successfully inserted!
#
# Row 24 successfully inserted!
#
# Row 25 successfully inserted!
#
# Row 26 successfully inserted!
#
# Row 27 successfully inserted!
#
# Row 28 successfully inserted!
#
# Row 29 successfully inserted!
#
# Row 30 successfully inserted!
#
# Row 31 successfully inserted!
#
# Row 32 successfully inserted!
#
# Row 33 successfully inserted!
#
# Row 34 successfully inserted!
#
# Row 35 successfully inserted!
#
# Row 36 successfully inserted!
#
# Row 37 successfully inserted!
#
# Row 38 successfully inserted!
#
# Row 39 successfully inserted!
#
# Row 40 successfully inserted!
#
# Row 41 successfully inserted!
#
# Row 42 successfully inserted!
#
# Row 43 successfully inserted!
#
# Row 44 successfully inserted!
#
# Row 45 successfully inserted!
#
# Row 46 successfully inserted!
#
# Row 47 successfully inserted!
#
# Row 48 successfully inserted!
#
# Row 49 successfully inserted!
#
# Row 50 successfully inserted!
#
# Row 51 successfully inserted!
#
# Row 52 successfully inserted!
#
# Row 53 successfully inserted!
#
# Row 54 successfully inserted!
#
# Row 55 successfully inserted!
#
# Row 56 successfully inserted!
#
# Row 57 successfully inserted!
#
# Row 58 successfully inserted!
#
# Row 59 successfully inserted!
#
# Row 60 successfully inserted!
#
# Row 61 successfully inserted!
#
# Row 62 successfully inserted!
#
# Row 63 successfully inserted!
#
# Row 64 successfully inserted!
#
# Row 65 successfully inserted!
#
# Row 66 successfully inserted!
#
# Row 67 successfully inserted!
#
# Row 68 successfully inserted!
#
# Row 69 successfully inserted!
#
# Row 70 successfully inserted!
#
# Row 71 successfully inserted!
#
# Row 72 successfully inserted!
#
# Row 73 successfully inserted!
#
# Row 74 successfully inserted!
#
# Row 75 successfully inserted!
#
# Row 76 successfully inserted!
#
# Row 77 successfully inserted!
#
# Row 78 successfully inserted!
#
# Row 79 successfully inserted!
#
# Row 80 successfully inserted!
#
# Row 81 successfully inserted!
#
# Row 82 successfully inserted!
#
# Row 83 successfully inserted!
#
# Row 84 successfully inserted!
#
# Row 85 successfully inserted!
#
# Row 86 successfully inserted!
#
# Row 87 successfully inserted!
#
# Row 88 successfully inserted!
#
# Row 89 successfully inserted!
#
# Row 90 successfully inserted!
#
# Row 91 successfully inserted!
#
# Row 92 successfully inserted!
#
# Row 93 successfully inserted!
#
# Row 94 successfully inserted!
#
# Row 95 successfully inserted!
#
# Row 96 successfully inserted!
#
# Row 97 successfully inserted!
#
# Row 98 successfully inserted!
#
# Row 99 successfully inserted!
#
# Row 100 successfully inserted!
#
# Row 101 successfully inserted!
#
# Row 102 successfully inserted!
#
# Row 103 successfully inserted!
#
# Row 104 successfully inserted!
#
# Row 105 successfully inserted!
#
# Row 106 successfully inserted!
#
# Row 107 successfully inserted!
#
# Row 108 successfully inserted!
#
# Row 109 successfully inserted!
#
# Row 110 successfully inserted!
#
# Row 111 successfully inserted!
#
# Row 112 successfully inserted!
#
# Row 113 successfully inserted!
#
# Row 114 successfully inserted!
#
# Row 115 successfully inserted!
#
# Row 116 successfully inserted!
#
# Row 117 successfully inserted!
#
# Row 118 successfully inserted!
#
# Row 119 successfully inserted!
#
# Row 120 successfully inserted!
#
# Row 121 successfully inserted!
#
# Row 122 successfully inserted!
#
# Row 123 successfully inserted!
#
# Row 124 successfully inserted!
#
# Row 125 successfully inserted!
#
# Row 126 successfully inserted!
#
# Row 127 successfully inserted!
#
# Row 128 successfully inserted!
#
# Row 129 successfully inserted!
#
# Row 130 successfully inserted!
#
# Row 131 successfully inserted!
#
# Row 132 successfully inserted!
#
# Row 133 successfully inserted!
#
# Row 134 successfully inserted!
#
# Row 135 successfully inserted!
#
# Row 136 successfully inserted!
#
# Row 137 successfully inserted!
#
# Row 138 successfully inserted!
#
# Row 139 successfully inserted!
#
# Row 140 successfully inserted!
#
# Row 141 successfully inserted!
#
# Row 142 successfully inserted!
#
# Row 143 successfully inserted!
#
# Row 144 successfully inserted!
#
# Row 145 successfully inserted!

# %% [markdown]
# ### Run Summary Stats to find meaningful insights

# %% [markdown]
# Find this vehicle's market average price by condition(New/Used/Certified Used)

# %%
file_name #print database name composed by user input
# Out:
# 'toyota_camry_2019_2020_77002_50miles'

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Condition",
            "avgPrice": {"$avg": "$List Price"}
        }
    }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Used', 'avgPrice': 22144.443396226416}
# {'_id': 'New', 'avgPrice': 34439.2}
# {'_id': 'Certified', 'avgPrice': 22637.571428571428}

# %% [markdown]
# Find this vehicle's average listing price by Seller Type

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Seller Type",
            "Average Price": {"$avg": "$List Price"}
        }
    }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Dealer', 'Average Price': 23094.131944444445}

# %% [markdown]
# Find how many dealers and how many private sellers who sell this vehicle

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Seller Type",
            "Count": {"$sum": 1}
        }
    }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Dealer', 'Count': 146}

# %% [markdown]
# Find this vehicle's market average price by exterior color (Limit to Top 10 by price)

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Exterior Color",
            "Average Price": {"$avg": "$List Price"}
        }
    },
    { "$sort": { "Average Price": -1 } },
    { "$limit": 10 }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Wind Chill Pearl/Midnight Black Metallic', 'Average Price': 40234.333333333336}
# {'_id': 'Celestial Silver/Midnight Black Metallic', 'Average Price': 31295.0}
# {'_id': 'Supersonic Red', 'Average Price': 26577.0}
# {'_id': 'Wind Chill Pearl', 'Average Price': 25447.8}
# {'_id': 'Blue Streak Metallic', 'Average Price': 25373.375}
# {'_id': 'Silver', 'Average Price': 24524.2}
# {'_id': 'Red', 'Average Price': 23424.571428571428}
# {'_id': 'Predawn Gray Mica', 'Average Price': 23370.9}
# {'_id': 'Gray', 'Average Price': 23272.0}
# {'_id': 'Black', 'Average Price': 22941.23076923077}

# %% [markdown]
# Find this vehicle's market average price by trim level

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Trim Level",
            "Average Price": {"$avg": "$List Price"}
        }
    },
    { "$sort": { "Average Price": -1 } }
])

for r in result:
    print(r)
# Out:
# {'_id': 'XSE V6', 'Average Price': 34912.5}
# {'_id': 'XLE Hybrid', 'Average Price': 34538.0}
# {'_id': 'XLE V6', 'Average Price': 30994.0}
# {'_id': 'XSE AWD', 'Average Price': 29780.0}
# {'_id': 'XSE', 'Average Price': 28129.941176470587}
# {'_id': 'XLE', 'Average Price': 27784.375}
# {'_id': 'XSE w/ Carpet Mat Package', 'Average Price': 26980.0}
# {'_id': 'LE Hybrid', 'Average Price': 26863.8}
# {'_id': 'XSE w/ Navigation Package', 'Average Price': 24950.0}
# {'_id': 'None', 'Average Price': 21931.0}
# {'_id': 'SE', 'Average Price': 21382.737704918032}
# {'_id': 'LE', 'Average Price': 19557.85714285714}
# {'_id': 'L', 'Average Price': 19146.333333333332}

# %% [markdown]
# Find this vehicle's market average price first by condition and second by trim level

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": 
                {"condition":"$Condition",
                 "trim":"$Trim Level"},
            "Average Price": {"$avg": "$List Price"}
        }
    },
    { "$sort": { "Average Price": -1 } }
])

for r in result:
    print(r)
# Out:
# {'_id': {'condition': 'New', 'trim': 'XSE V6'}, 'Average Price': 40999.333333333336}
# {'_id': {'condition': 'New', 'trim': 'XSE'}, 'Average Price': 38421.0}
# {'_id': {'condition': 'New', 'trim': 'XLE'}, 'Average Price': 36596.0}
# {'_id': {'condition': 'New', 'trim': 'XLE Hybrid'}, 'Average Price': 34538.0}
# {'_id': {'condition': 'Certified', 'trim': 'XSE'}, 'Average Price': 31738.0}
# {'_id': {'condition': 'Used', 'trim': 'XLE V6'}, 'Average Price': 30994.0}
# {'_id': {'condition': 'Used', 'trim': 'XSE AWD'}, 'Average Price': 29780.0}
# {'_id': {'condition': 'Used', 'trim': 'XSE V6'}, 'Average Price': 28825.666666666668}
# {'_id': {'condition': 'New', 'trim': 'LE Hybrid'}, 'Average Price': 27959.75}
# {'_id': {'condition': 'Used', 'trim': 'XSE w/ Carpet Mat Package'}, 'Average Price': 26980.0}
# {'_id': {'condition': 'Used', 'trim': 'XSE'}, 'Average Price': 26879.428571428572}
# {'_id': {'condition': 'Used', 'trim': 'XLE'}, 'Average Price': 26788.333333333332}
# {'_id': {'condition': 'Certified', 'trim': 'XLE'}, 'Average Price': 26328.5}
# {'_id': {'condition': 'Used', 'trim': 'XSE w/ Navigation Package'}, 'Average Price': 24950.0}
# {'_id': {'condition': 'Used', 'trim': 'LE Hybrid'}, 'Average Price': 22480.0}
# {'_id': {'condition': 'Used', 'trim': 'None'}, 'Average Price': 21931.0}
# {'_id': {'condition': 'Certified', 'trim': 'SE'}, 'Average Price': 21770.9}
# {'_id': {'condition': 'Used', 'trim': 'SE'}, 'Average Price': 21306.62745098039}
# {'_id': {'condition': 'Certified', 'trim': 'LE'}, 'Average Price': 20612.75}
# {'_id': {'condition': 'Used', 'trim': 'L'}, 'Average Price': 19146.333333333332}
# {'_id': {'condition': 'Used', 'trim': 'LE'}, 'Average Price': 19007.478260869564}

# %% [markdown]
# Find what exterior colors are popular in the market

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "$Exterior Color",
            "Count": {"$sum": 1}
        }
    },
    { "$sort": { "Count": -1 } }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Celestial Silver Metallic', 'Count': 17}
# {'_id': 'Super White', 'Count': 14}
# {'_id': 'Black', 'Count': 13}
# {'_id': 'Silver', 'Count': 11}
# {'_id': 'Blue', 'Count': 11}
# {'_id': 'White', 'Count': 10}
# {'_id': 'Predawn Gray Mica', 'Count': 10}
# {'_id': 'Blue Streak Metallic', 'Count': 8}
# {'_id': 'Red', 'Count': 7}
# {'_id': 'None', 'Count': 7}
# {'_id': 'Midnight Black Metallic', 'Count': 6}
# {'_id': 'Wind Chill Pearl', 'Count': 5}
# {'_id': 'Galactic Aqua Mica', 'Count': 4}
# {'_id': 'Wind Chill Pearl/Midnight Black Metallic', 'Count': 3}
# {'_id': 'Gray', 'Count': 3}
# {'_id': 'Supersonic Red', 'Count': 3}
# {'_id': 'Brownstone', 'Count': 3}
# {'_id': 'Celestial Silver/Midnight Black Metallic', 'Count': 2}
# {'_id': 'Silver Me.', 'Count': 2}
# {'_id': 'Ruby Flare Pearl', 'Count': 2}
# {'_id': 'Midnight Black', 'Count': 2}
# {'_id': 'Aqua', 'Count': 1}
# {'_id': 'Attitude Black Mc.', 'Count': 1}
# {'_id': 'Brown', 'Count': 1}

# %% [markdown]
# Find this vehicle's average listing price from dealers that have ratings higher than 4.0

# %%
result = mycollection.aggregate([
    { "$match": { "Seller Rating": { "$gte": 4.0} } },
    {
        "$group": {
            "_id": "4.0+",
            "Average Price": {"$avg": "$List Price"}
        }
    },
    { "$sort": { "Average Price": -1 } }
])

for r in result:
    print(r)
# Out:
# {'_id': '4.0+', 'Average Price': 23138.264957264957}

# %% [markdown]
# Find dealer's average rating

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": "Dealer Rating",
            "Average Rating": {"$avg": "$Seller Rating"}
        }
    },
    { "$sort": { "Average Rating": -1 } }
])

for r in result:
    print(r)
# Out:
# {'_id': 'Dealer Rating', 'Average Rating': 4.521311475409837}

# %% [markdown]
# Find the seller contact information who has lowest listing price

# %%
result = mycollection.aggregate([
    {
        "$group": {
            "_id": {
                "Seller Name":"$Seller Name",
                "Seller Phone Number":"$Seller Phone Number"
            },
            "Min Price": {"$min": "$List Price"}
        }
    },
    { "$sort": { "Min Price": 1 } }
])

for r in result:
    print(r)
    break
# Out:
# {'_id': {'Seller Name': 'Strawberry Road Auto Sales', 'Seller Phone Number': '(832) 650-0197'}, 'Min Price': None}
